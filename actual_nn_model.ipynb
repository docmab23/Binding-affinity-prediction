# %%
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from matplotlib import pyplot as plt
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings 
from xgboost import XGBRegressor
from keras.layers import LeakyReLU
from sklearn import preprocessing
from sklearn.svm import SVR
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
# Out:
# Using TensorFlow backend.
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\Administrator\Anaconda3\envs\my-rdkit-env\lib\site-packages\tensorflow_core\python\pywrap_tensorflow.py", line 58, in <module>
#     from tensorflow.python.pywrap_tensorflow_internal import *
#   File "C:\Users\Administrator\Anaconda3\envs\my-rdkit-env\lib\site-packages\tensorflow_core\python\pywrap_tensorflow_internal.py", line 28, in <module>
#     _pywrap_tensorflow_internal = swig_import_helper()
#   File "C:\Users\Administrator\Anaconda3\envs\my-rdkit-env\lib\site-packages\tensorflow_core\python\pywrap_tensorflow_internal.py", line 24, in swig_import_helper
#     _mod = imp.load_module('_pywrap_tensorflow_internal', fp, pathname, description)
# ...

# %%
class Data:
    def __init__(self,data,target):
        self.data = data
        self.target = target
        #self.data = self.data.drop(["Unnamed: 0"],1)
        #self.data = self.data.values
        #self.data = np.array(self.data)
        #self.target = np.load('target.npy',allow_pickle=True)
        #self.target = np.reshape(self.target,(411,1))
        #self.target = pd.DataFrame(data=self.target)
        #self.target = self.target.values
        #self.target = self.target.drop(["Unnamed: 0"],1)
        #self.target = self.target.replace(">10000",int(10000))
        #self.target=  self.target.replace(">100000",int(100000))
        #self.target = self.target.replace(">3700",int(3700))
        self.input_dim = self.data.shape[1]
    def show_data(self):
        return self.data
    def show_target(self):
        return self.target
    def standardize(self):
        self.x = self.data.values #returns a numpy array
        self.min_max_scaler = preprocessing.MinMaxScaler()
        self.x_scaled = self.min_max_scaler.fit_transform(self.data)
        return self.x_scaled
class model(Data):
    def __init__(self):
        self.NN_model = Sequential()
        self.NN_model.add(Dense(512, kernel_initializer='normal',input_dim=426,activation='sigmoid'))
        #self.NN_model.add(LeakyReLU(alpha=0.1))
        self.NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
        self.NN_model.add(Dense(128, kernel_initializer='normal',activation='relu'))
        self.NN_model.add(Dense(64, kernel_initializer='normal',activation='sigmoid'))
        self.NN_model.add(Dense(32, kernel_initializer='normal',activation='sigmoid'))
        #self.NN_model.add(LeakyReLU(alpha=0.1))
        self.NN_model.add(Dense(10, kernel_initializer='normal',activation='sigmoid'))

        # The Output Layer :
        self.NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

        # Compile the network :
        self.NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
    def get_summary(self):
        self.NN_model.summary()
    def fit_model(self,X,y,epochs):
        self.checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
        self.checkpoint = ModelCheckpoint(self.checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
        self.callbacks_list = [self.checkpoint]
        self.NN_model.fit(X,y,epochs=epochs,validation_split = 0.2)
        self.wights_file = 'Weights-478--18738.19831.hdf5' # choose the best checkpoint 
        self.NN_model.load_weights(self.wights_file) # load it
        self.NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
data = pd.read_csv('ff_x.csv')
target = np.load("ff_y.npy",allow_pickle=True)
#total = pd.concat([data,target],axis=1)
data = data.drop(["Unnamed: 0"],1)
#data = np.array(data)
'''all_ = pd.DataFrame(data=data)
all_['target'] = target
all_ = all_.sample(frac=1)
X = all_.drop(["target"],1)
y = all_['target']'''
data.replace([np.inf, -np.inf], np.nan, inplace=True) 
data = data.fillna(0)
data = data.iloc[:,0:425]
da = Data(data,target)
y=np.ravel(da.target)
std_data =da.standardize()
NN = model()
NN.fit_model(std_data,y,30)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-ebf9eb9fd3d5> in <module>
#      16 std_data =da.standardize()
#      17 NN = model()
# ---> 18 NN.fit_model(std_data,y,30)
#
# <ipython-input-32-16d75434292e> in fit_model(self, X, y, epochs)
#      47         self.checkpoint = ModelCheckpoint(self.checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
#      48         self.callbacks_list = [self.checkpoint]
# ---> 49         self.NN_model.fit(X,y,epochs=epochs,validation_split = 0.2)
#      50         self.wights_file = 'Weights-478--18738.19831.hdf5' # choose the best checkpoint
#      51         self.NN_model.load_weights(self.wights_file) # load it
#
# ...

# %%
y = pd.read_csv("Ki.csv")
y= y.replace(">10000",int(10000))
y=  y.replace(">100000",int(100000))
y = y.replace(">3700",int(3700))

y.to_csv("Ki2.csv")

# %%
def get_cols_with_no_nans(df,col_type):
    '''
    Arguments :
    df : The dataframe to process
    col_type : 
          num : to only get numerical columns with no nans
          no_num : to only get nun-numerical columns with no nans
          all : to get any columns with no nans    
    '''
    if (col_type == 'num'):
        predictors = df.select_dtypes(exclude=['object'])
    elif (col_type == 'no_num'):
        predictors = df.select_dtypes(include=['object'])
    elif (col_type == 'all'):
        predictors = df
    else :
        print('Error : choose a type (num, no_num, all)')
        return 0
    cols_with_no_nans = []
    for col in predictors.columns:
        if not df[col].isnull().any():
            cols_with_no_nans.append(col)
    return cols_with_no_nans

# %%
import pandas as pd
df = pd.read_csv("model_data.csv")
tar = pd.read_csv("Ki2.csv")
len(get_cols_with_no_nans(df,"no_num"))
# Out:
# 0

# %%
print(np.any(np.isnan(tar)))
# Out:
# False

# %%
X = pd.read_csv("X2.csv")
y = pd.read_csv("Y2.csv")

# %%
np.array(y).shape
# Out:
# (410, 2)

# %%
model_ = model()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4c7205bf516f> in <module>
# ----> 1 model_ = model()
#
# <ipython-input-1-16d75434292e> in __init__(self)
#      26 class model(Data):
#      27     def __init__(self):
# ---> 28         self.NN_model = Sequential()
#      29         self.NN_model.add(Dense(512, kernel_initializer='normal',input_dim=426,activation='sigmoid'))
#      30         #self.NN_model.add(LeakyReLU(alpha=0.1))
#
# NameError: name 'Sequential' is not defined
